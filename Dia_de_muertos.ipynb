# %%
import requests # Package REQUEST pour Scrapping: Effectue un requete HTTP et Recupère du code HTML brut
from bs4 import BeautifulSoup # pour PARSING (morceler, séquencer) pour extraire des informations spécifiques et non toute la page avec le code HTTML
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re

# %%
pip install WordCloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Extraction de l'article : WEBSCRAPPING
url = "https://www.lepoint.fr/services/el-dia-de-muertos-tout-savoir-sur-cette-fete-mexicaine-02-11-2022-2496162_4345.php#11"
response = requests.get(url)
html_content = response.text

# %%
print(html_content)
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" class="no-js" lang="fr">    <head>
# <!--COL CHH223 -->
# <!--BLOC WWW - HEAD - DEV - HEADER PRELOAD-->
# <!--bH:-->
# <link rel="preconnect" href="https://static-images.lpnt.fr" crossorigin>
# <link rel="preconnect" href="https://www.googletagmanager.com">
# <!--/BLOC WWW - HEAD - DEV - HEADER PRELOAD-->
# <!--BLOC WWW - HTMLHEADER - Htmlheader 2023 - DYN-->
# <!--bMexe - t_www_2023/structure/head_exec.tpl-->
# <meta charset="UTF-8">
# <meta name="copyright" content="Le Point">
# <link rel="canonical" href="https://www.lepoint.fr/services/el-dia-de-muertos-tout-savoir-sur-cette-fete-mexicaine-02-11-2022-2496162_4345.php">
# <meta property="fb:page_id" content="49173930702">
# <meta property="twitter:account_id" content="1597951100">
# <meta property="fb:app_id" content="260897067396268">
# <meta property="fb:pages" content="49173930702">
# <meta property="fb:pages" content="1696002587283393">
# ...

# %%
soup = BeautifulSoup(html_content, "html.parser")
article_text = soup.get_text()

# %%
print(article_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# El Día de Muertos : tout savoir sur cette fête mexicaine
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Lire le numéro
#
#
#
# Le Point
# Services
#
#
#
#
#
#
#
#
# Mon compte
#
#
#
#
# Mon profil
#
#
#
#
#
# Mes favoris
#
#
#
#
#
# Mes alertes et mes newsletters
#
#
#
#
#
# Mes commentaires
#
#
#
#
#
# Mon abonnement
#
#
#
#
#
# Se déconnecter
#
#
#
#
#
#
# Se connecter
#
#
#
# S'abonner
#
#
#
#
#
#
#
#
#
# Politique
#
#
# International
#
#
# Débats
#
#
# Économie
#
#
# Culture
#
#
# Style
#
#
# Services
#
#
# Événements
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rechercher
#
# Appuyez sur la touche échap pour fermer la recherche.
#
#
#
# Accueil
#
# Politique
# Emmanuel Macron
# Elisabeth Borne
#
#
#
# International
# Niger
# Lettre de Bruxelles
# Lettre de Buckingham
# ...

# %%
 # Extraction du titre de l'article, le header et le contenu du corps de l'article et l'image. 
# Ici j'extrais suelement les informations qui m'interessent
# quelle balise contient les info que je cherche

title = soup.find("h1").get_text().strip() # OR title = soup.title.text.strip()
#title
#title # OR print("Titre de la page :", title)
#paragraph = soup.find_all("p") # pas possible de ".Get_text() sur une liste de P". Solution = liste en compréhension :
#all_paragraphs = [p.get_text().strip() for p in soup.find_all("p")]
#all_paragraphs
# Je cherche que le header
header = soup.find("header", id="haut").get_text().strip()
#header
#soup.find("body")
article_body = soup.find("div", id="contenu", class_="article-styles").get_text().strip()
#article_body
#figure = soup.find("img", src="/img-l/articles/2496162.png"

# %%
# Téléchargement des ressources pour nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anala\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anala\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Prétraitement du texte
tokens = nltk.word_tokenize(article_text)
#tokens = [word.lower() for word in tokens if word.isalpha()]
#stop_words = set(stopwords.words("english"))  # Vous pouvez utiliser le jeu de stopwords en français si nécessaire
#filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
tokens # Ceci a découpé mot pas mot l'ensemble du contenu texte de l'article, avec ".word_tokenize(article_text)"
# Out:
# ['El',
#  'Día',
#  'de',
#  'Muertos',
#  ':',
#  'tout',
#  'savoir',
#  'sur',
#  'cette',
#  'fête',
#  'mexicaine',
#  'Lire',
#  'le',
#  'numéro',
#  'Le',
#  'Point',
#  'Services',
#  'Mon',
#  'compte',
#  'Mon',
#  'profil',
#  'Mes',
#  'favoris',
#  'Mes',
#  'alertes',
#  'et',
#  'mes',
#  'newsletters',
#  'Mes',
#  'commentaires',
#  'Mon',
#  'abonnement',
#  'Se',
#  'déconnecter',
#  'Se',
#  'connecter',
#  "S'abonner",
#  'Politique',
#  'International',
#  'Débats',
#  'Économie',
#  'Culture',
#  'Style',
#  'Services',
#  'Événements',
#  'Rechercher',
#  'Appuyez',
#  'sur',
#  'la',
#  'touche',
#  'échap',
#  'pour',
#  'fermer',
#  'la',
#  'recherche',
#  '.',
#  'Accueil',
#  'Politique',
#  'Emmanuel',
#  'Macron',
#  'Elisabeth',
#  'Borne',
#  'International',
#  'Niger',
#  'Lettre',
#  'de',
#  'Bruxelles',
#  'Lettre',
#  'de',
#  'Buckingham',
#  'Guerre',
#  'en',
#  'Ukraine',
#  'Donald',
#  'Trump',
#  'Afrique',
#  'Débats',
#  'Éditos',
# ...

# %%
# Prétraitement du texte
tokens = nltk.word_tokenize(article_text)
tokens = [word.lower() for word in tokens if word.isalpha()]
#stop_words = set(stopwords.words("french"))  
#filtered_tokens = [word for word in tokens if word not in stop_words]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Prétraitement du texte
# ----> 2 tokens = nltk.word_tokenize(article_text)
#       3 tokens = [word.lower() for word in tokens if word.isalpha()]
#
# NameError: name 'nltk' is not defined

# %%
tokens
# Out:
# ['el',
#  'día',
#  'de',
#  'muertos',
#  'tout',
#  'savoir',
#  'sur',
#  'cette',
#  'fête',
#  'mexicaine',
#  'lire',
#  'le',
#  'numéro',
#  'le',
#  'point',
#  'services',
#  'mon',
#  'compte',
#  'mon',
#  'profil',
#  'mes',
#  'favoris',
#  'mes',
#  'alertes',
#  'et',
#  'mes',
#  'newsletters',
#  'mes',
#  'commentaires',
#  'mon',
#  'abonnement',
#  'se',
#  'déconnecter',
#  'se',
#  'connecter',
#  'politique',
#  'international',
#  'débats',
#  'économie',
#  'culture',
#  'style',
#  'services',
#  'événements',
#  'rechercher',
#  'appuyez',
#  'sur',
#  'la',
#  'touche',
#  'échap',
#  'pour',
#  'fermer',
#  'la',
#  'recherche',
#  'accueil',
#  'politique',
#  'emmanuel',
#  'macron',
#  'elisabeth',
#  'borne',
#  'international',
#  'niger',
#  'lettre',
#  'de',
#  'bruxelles',
#  'lettre',
#  'de',
#  'buckingham',
#  'guerre',
#  'en',
#  'ukraine',
#  'donald',
#  'trump',
#  'afrique',
#  'débats',
#  'éditos',
#  'le',
#  'postillon',
# ...

# %%
# Prétraitement du texte
tokens = nltk.word_tokenize(article_text)
tokens = [word.lower() for word in tokens if word.isalpha()]
stop_words = set(stopwords.words("french"))  
#filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
stop_words
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
# ...

# %%
filtered_tokens = [word for word in tokens if word not in stop_words]
filtered_tokens
# Out:
# ['el',
#  'día',
#  'muertos',
#  'tout',
#  'savoir',
#  'cette',
#  'fête',
#  'mexicaine',
#  'lire',
#  'numéro',
#  'point',
#  'services',
#  'compte',
#  'profil',
#  'favoris',
#  'alertes',
#  'newsletters',
#  'commentaires',
#  'abonnement',
#  'déconnecter',
#  'connecter',
#  'politique',
#  'international',
#  'débats',
#  'économie',
#  'culture',
#  'style',
#  'services',
#  'événements',
#  'rechercher',
#  'appuyez',
#  'touche',
#  'échap',
#  'fermer',
#  'recherche',
#  'accueil',
#  'politique',
#  'emmanuel',
#  'macron',
#  'elisabeth',
#  'borne',
#  'international',
#  'niger',
#  'lettre',
#  'bruxelles',
#  'lettre',
#  'buckingham',
#  'guerre',
#  'ukraine',
#  'donald',
#  'trump',
#  'afrique',
#  'débats',
#  'éditos',
#  'postillon',
#  'économie',
#  'immobilier',
#  'médias',
#  'argent',
#  'société',
#  'faits',
#  'divers',
#  'justice',
#  'sciences',
#  'innovations',
#  'environnement',
#  'astronomie',
#  'sciences',
#  'évènement',
# ...
